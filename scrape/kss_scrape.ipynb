# %%
from urllib.request import urlopen
from urllib.parse import quote, unquote
from lxml import html
from glob import glob
import re

from functools import cache
import pathlib
import os

# %%
def num_to_devanagari(n):
    """Converts a number to devanagari"""
    devanagari = "०१२३४५६७८९"
    return "".join([devanagari[int(i)] for i in str(n)])

def kss_url(lambaka, taranga=None):
    """Returns the url for a given lambaka and taranga"""
    lambaka = num_to_devanagari(lambaka)
    if taranga is None:
        return f"https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_{lambaka}"
    
    taranga = num_to_devanagari(taranga)
    return f"https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_{lambaka}/तरङ्गः_{taranga}"

# def get_url_of_anchors(url, matches=r"/wiki/कथासरित्सागरः/लम्बकः_[०१२३४५६७८९]+/तरङ्गः_[०१२३४५६७८९]+"):
# def get_url_of_anchors(url, matches=r"/wiki/कथासरित्सागरः/लम्बकः_[०१२३४५६७८९]+/तर.*गः_[०१२३४५६७८९]+"):
def get_url_of_anchors(url, matches=r"/wiki/कथासरित्सागरः/लम्बकः_[०१२३४५६७८९]+/तर.*"):
    """Returns the url of all the anchors in a given url"""
    print(url)
    url = quote(url, safe='/:')
    try:
        page = urlopen(url)
    except:
        print("Error: ", url)
        return []
    
    tree = html.fromstring(page.read())
    hrefs = tree.xpath('//a/@href')
    # decode the url
    # hrefs = [href.encode('utf-8').decode('unicode_escape') for href in hrefs]
    # unquote the url
    hrefs = [unquote(href) for href in hrefs]
    # filter the hrefs
    hrefs = [href for href in hrefs if re.search(matches, href)]
    return hrefs


@cache
def get_kss_urls():
    kss_urls = [ x for l in range(1, 19) for x in get_url_of_anchors(kss_url(l)) ]
    return [ f"https://sa.wikisource.org{x}" for x in kss_urls if len(x) > 0 ]

# %%
@cache
def get_kss_text(url, xpath="//div[@class='poem']//span//text()"):
    """Returns the text of a given url"""

    url = quote(url, safe='/:')
    # print(url)
    try:
        page = urlopen(url)
    except Exception as e:
        print(f"Error: {e}\n{unquote(url)}\n", url)
        return []
    
    tree = html.fromstring(page.read())
    text = tree.xpath(xpath)
    text = [x for x in text]
    return text

# %%
kss_urls = get_kss_urls()
for url in kss_urls[:]:
    print(url)
    # (lambaka, taranga) = re.findall(r"लम्बकः_([०१२३४५६७८९]+)/तरङ्गः_([०१२३४५६७८९]+)", url)[0]
    (lambaka, taranga) = re.findall(r"लम्बकः_([०१२३४५६७८९]+)/तर.*_([०१२३४५६७८९]+)", url)[0]
    lambaka = int(lambaka)
    taranga = int(taranga)
    l,t = (num_to_devanagari(x) for x in (lambaka, taranga))
    filename = f"~scraped-topic/kss/kss_{lambaka:02d}_{taranga:02d}.md"
    print(filename)
    pathlib.Path(os.path.dirname(filename)).mkdir(parents=True, exist_ok=True)
    seen =v=0
    with open(filename, 'w') as f:
        f.write(f"## [कथासरित्सागरः {lambaka:02d} {taranga:02d}]({url})\n\n")
        txt = get_kss_text(url)
        txt = [ x.strip() for x in txt]
        txt = [ x for x in txt if len(x)>3]
        txt = [ re.sub(r"\s*।।\s*", " ॥ ", x) for x in txt]
        txt = [ re.sub(r"\s*।s*", " । ", x) for x in txt]
        # remove newlines
        txt = [ re.sub(r"\n+", "", x) for x in txt]
        txt = [ [
            # re.sub(r"(\s*॥\s*([०१२३४५६७८९]+\s*)?)", r"\1" + f"( {l}-{t}-{num_to_devanagari(1+v//2)} )\n\n", x)
            # re.sub(r"((\s*॥\s*([०१२३४५६७८९]+\s*)?)|(\s*.\s*([०१२३४५६७८९]+\s*){1}))" , r"\1" + f"( {l}-{t}-{num_to_devanagari(1+v//2)} )" + f"\n\n", x)
            # re.sub(r"((\s*॥\s*([०१२३४५६७८९]+\s*)?)|(\s*.\s*([०१२३४५६७८९]+\s*){1}))" , r"\1" + f" ({lambaka}-{taranga}-{(1+v//2)})\n" + f"\n\n", x)
            0
            , seen := seen + (1 if (seen!=0 or re.search(r"॥\s*[०१२३४५६७८९०]+", x)) else 0)
            , v:=v+(1 if seen>0 else 0)
            , re.sub(r"((\s*॥\s*([०१२३४५६७८९]+\s*)?)|(\s*.\s*([०१२३४५६७८९]+\s*){1}))$" 
                     , r"\1" 
                     + (f" ({lambaka}-{taranga}-{(1+v//2)})\n" if seen>0 else "")
                     + f"\n\n"
                     , x)
            ][-1] for x in txt]

        # txt = [ re.sub(r"^", "### ", x) if '॥'  in x else x for x in txt]
        txt = "".join(txt)
        txt = re.sub(r"^", "### ", txt)
        txt = re.sub(r"\n+", "\n\n### ", txt)
        f.write(txt)
# get_kss_text(kss_urls[0])
# Out:
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_४
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_५
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_११
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१३
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१४
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१५
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१६
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_१
# ~scraped-topic/kss/kss_01_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्ः_२
# ~scraped-topic/kss/kss_01_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_३
# ~scraped-topic/kss/kss_01_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्ः_४
# ~scraped-topic/kss/kss_01_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_५
# ~scraped-topic/kss/kss_01_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_६
# ~scraped-topic/kss/kss_01_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_७
# ~scraped-topic/kss/kss_01_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१/तरङ्गः_८
# ~scraped-topic/kss/kss_01_08.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_१
# ~scraped-topic/kss/kss_02_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_२
# ~scraped-topic/kss/kss_02_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_३
# ~scraped-topic/kss/kss_02_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_४
# ~scraped-topic/kss/kss_02_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_५
# ~scraped-topic/kss/kss_02_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_२/तरङ्गः_६
# ~scraped-topic/kss/kss_02_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_१
# ~scraped-topic/kss/kss_03_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_२
# ~scraped-topic/kss/kss_03_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_३
# ~scraped-topic/kss/kss_03_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_४
# ~scraped-topic/kss/kss_03_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_५
# ~scraped-topic/kss/kss_03_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_३/तरङ्गः_६
# ~scraped-topic/kss/kss_03_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_४/तरङ्गः_१
# ~scraped-topic/kss/kss_04_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_४/तरङ्गः_२
# ~scraped-topic/kss/kss_04_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_४/तरङ्गः_३
# ~scraped-topic/kss/kss_04_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_५/तरङ्गः_१
# ~scraped-topic/kss/kss_05_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_५/तरङ्गः_२
# ~scraped-topic/kss/kss_05_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_५/तरङ्गः_३
# ~scraped-topic/kss/kss_05_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_१
# ~scraped-topic/kss/kss_06_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_२
# ~scraped-topic/kss/kss_06_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_३
# ~scraped-topic/kss/kss_06_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_४
# ~scraped-topic/kss/kss_06_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_५
# ~scraped-topic/kss/kss_06_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_६
# ~scraped-topic/kss/kss_06_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_७
# ~scraped-topic/kss/kss_06_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_६/तरङ्गः_८
# ~scraped-topic/kss/kss_06_08.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_१
# ~scraped-topic/kss/kss_07_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_२
# ~scraped-topic/kss/kss_07_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_३
# ~scraped-topic/kss/kss_07_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_४
# ~scraped-topic/kss/kss_07_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_५
# ~scraped-topic/kss/kss_07_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_६
# ~scraped-topic/kss/kss_07_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_७
# ~scraped-topic/kss/kss_07_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_८
# ~scraped-topic/kss/kss_07_08.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_७/तरङ्गः_९
# ~scraped-topic/kss/kss_07_09.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_१
# ~scraped-topic/kss/kss_08_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_२
# ~scraped-topic/kss/kss_08_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_३
# ~scraped-topic/kss/kss_08_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_४
# ~scraped-topic/kss/kss_08_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_५
# ~scraped-topic/kss/kss_08_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_६
# ~scraped-topic/kss/kss_08_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_८/तरङ्गः_७
# ~scraped-topic/kss/kss_08_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_१
# ~scraped-topic/kss/kss_09_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_२
# ~scraped-topic/kss/kss_09_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_३
# ~scraped-topic/kss/kss_09_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_४
# ~scraped-topic/kss/kss_09_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_५
# ~scraped-topic/kss/kss_09_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_९/तरङ्गः_६
# ~scraped-topic/kss/kss_09_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_१
# ~scraped-topic/kss/kss_10_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_२
# ~scraped-topic/kss/kss_10_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_३
# ~scraped-topic/kss/kss_10_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_४
# ~scraped-topic/kss/kss_10_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_५
# ~scraped-topic/kss/kss_10_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_६
# ~scraped-topic/kss/kss_10_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_७
# ~scraped-topic/kss/kss_10_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_८
# ~scraped-topic/kss/kss_10_08.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_९
# ~scraped-topic/kss/kss_10_09.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१०/तरङ्गः_१०
# ~scraped-topic/kss/kss_10_10.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_११/तरङ्ग_१
# ~scraped-topic/kss/kss_11_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०१
# ~scraped-topic/kss/kss_12_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०२
# ~scraped-topic/kss/kss_12_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०३
# ~scraped-topic/kss/kss_12_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०४
# ~scraped-topic/kss/kss_12_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०५
# ~scraped-topic/kss/kss_12_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०६
# ~scraped-topic/kss/kss_12_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०७
# ~scraped-topic/kss/kss_12_07.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_०८
# ~scraped-topic/kss/kss_12_08.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_३३
# ~scraped-topic/kss/kss_12_33.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_३४
# ~scraped-topic/kss/kss_12_34.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_३५
# ~scraped-topic/kss/kss_12_35.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१२/तरङ्गः_३६
# ~scraped-topic/kss/kss_12_36.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१३/तरङ्गः_१
# ~scraped-topic/kss/kss_13_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१३/तरङ्गः_१
# ~scraped-topic/kss/kss_13_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१४/तरङ्गः_१
# ~scraped-topic/kss/kss_14_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१४/तरङ्गः_२
# ~scraped-topic/kss/kss_14_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१४/तरङ्गः_३
# ~scraped-topic/kss/kss_14_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१४/तरङ्गः_४
# ~scraped-topic/kss/kss_14_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१५/तरङ्गः_१
# ~scraped-topic/kss/kss_15_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१५/तरङ्गः_२
# ~scraped-topic/kss/kss_15_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१६/तरङ्गः_१
# ~scraped-topic/kss/kss_16_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१६/तरङ्गः_२
# ~scraped-topic/kss/kss_16_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१६/तरङ्गः_३
# ~scraped-topic/kss/kss_16_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_१
# ~scraped-topic/kss/kss_17_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_२
# ~scraped-topic/kss/kss_17_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_३
# ~scraped-topic/kss/kss_17_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_४
# ~scraped-topic/kss/kss_17_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_५
# ~scraped-topic/kss/kss_17_05.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१७/तरङ्गः_६
# ~scraped-topic/kss/kss_17_06.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८/तरङ्गः_१
# ~scraped-topic/kss/kss_18_01.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८/तरङ्गः_२
# ~scraped-topic/kss/kss_18_02.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८/तरङ्गः_३
# ~scraped-topic/kss/kss_18_03.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८/तरङ्गः_४
# ~scraped-topic/kss/kss_18_04.md
# https://sa.wikisource.org/wiki/कथासरित्सागरः/लम्बकः_१८/तरङ्गः_५
# ~scraped-topic/kss/kss_18_05.md
