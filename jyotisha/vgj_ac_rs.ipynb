# %% [markdown]
# # Transit of sun through the seasonal nakṣatra cycle in the Vṛddha-Gārgīya Jyotiṣa
# ## Indian Journal of History of Science, 56.3(2021)
# ###  Supplementary Material

# %%
import vgj_ac_rs as vgj_ac_rs
import warnings; warnings.simplefilter('ignore')
vgj_ac_rs.init_globals()
# Out:
# /Users/sunder/miniforge3/envs/tfmetal/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/sunder/miniforge3/envs/tfmetal/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utctai" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# WARNING: Tried to get polar motions for times before IERS data is valid. Defaulting to polar motion from the 50-yr mean for those. This may affect precision at the arcsec level. Please check your astropy.utils.iers.conf.iers_auto_url and point it to a newer version if necessary. [astropy.coordinates.builtin_frames.utils]
# /Users/sunder/miniforge3/envs/tfmetal/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "utcut1" yielded 1 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/sunder/miniforge3/envs/tfmetal/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "taiutc" yielded 1 of "dubious year (Note 4)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# /Users/sunder/miniforge3/envs/tfmetal/lib/python3.9/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "epv00" yielded 1 of "warning: date outsidethe range 1900-2100 AD"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),

# %% [markdown]
# ## Fig 1 - Yearly variation of the nakṣatra location error Ey in the seasonal solar zodiac of VGJ.
# - The green curves (....83 stars; ___ 27 proxy stars; -.-.-. 9 seasonal nakṣatra) refer to the Ādityacāra data of the 11th Section of VGJ.
# - The 83 constituent and the 27 proxy stars are as per Table 1.
# - Errors for the nine seasonal nakṣatra boundaries remain zero during 1210-1150 BCE.
# - The red curves refer to the twelve month solar nakṣatra data available in the 59th Section titled Ṛtusvabhāva.

# %%
vgj_ac_rs.fig1()

# %% [markdown]
# ## Fig. 2. Error sensitivity for possible identification of Vedic star śraviṣṭhā as β Aquari and śravaṇa as β Delphini.
#
# - The readjusted 27 proxy stars and the yogatāras of Abhyankar lead to almost the same result of c 1250 BCE for the error minimum.
# - Errors for the nine seasonal nakṣatra boundaries remain zero during 1700–1350 BCE.

# %%
vgj_ac_rs.fig2()

# %% [markdown]
# ## Fig.3. Twelve month (madhu-tapasya) or (caitra-phālguna) sun’s transit in 500 BCE as per the Ṛtusvabhāva (59th aṅga) of VGJ.
#
# - The points are joined smoothly for better visualization with markings for the seasons and the months.
# - It can be verified that all the twelve nakṣatra named in the VGJ text would have been visible sometime in the specified months.

# %%
vgj_ac_rs.fig3()

# %% [markdown]
# ##  One Year full moon overlaid on Seasons and Nakṣatras for -1500

# %%
vgj_ac_rs.plot_n83_ll(yrs=[-1500])

# %%
vgj_ac_rs.plot_n83_ll(yrs=[-500])

# %% [markdown]
# ##  One Year full moon overlaid on Seasons and Nakṣatras for -1500
# - Plot of RA and Dec and Full Moon size indicated

# %%
vgj_ac_rs.plot_n83_rd()

# %%
vgj_ac_rs.plot_n83_rd(yrs=[-500, -1000, -1500, -1999])

# %% [markdown]
# ## One Month moon overlaid on Seasons and Nakṣatras for -1500
# - Plot of RA and Dec ; Black is krishna paksha, Blue is shukla paksha
# - Size indicates the phase of the moon

# %%
# vgj_ac_rs.plot_n83_rd(yrs=[-500, -1000, -1500, -1999], moon_overlay='phase')
vgj_ac_rs.plot_n83_rd_with_moon_overlay()
# Out:
# <Axes: title={'center': 'Moon Path - two nakshatra cycles - at -500\n Blue is shukla paksha and black krishna'}>

# %% [markdown]
# ## Plot of Nakṣatra locations in their respective divisions
# - Red Band indicates where the nakṣatra bound is highest

# %%
vgj_ac_rs.do_bounded_plot(vgj_ac_rs.n27Feb24, "All 27")

# %% [markdown]
# ## Seasons per Ādityacāra
# ```
#   श्रविष्ठादीनि चत्वारि पौष्णार्धञ्च दिवाकरः । वर्धयन् सरसस्तिक्तं मासौ तपति शैशिरे ॥
#   रोहिण्यन्तानि विचरन् पौष्णार्धाद्याच्च भानुमान् । मासौ तपति वासन्तौ कषायं वर्धयन् रसम् ॥
#   सार्पार्धान्तानि विचरन् सौम्याद्यानि तु भानुमान् । ग्रैष्मिकौ तपते मासौ कटुकं वर्धयन् रसम् ॥
#   सावित्रान्तानि विचरन् सार्पार्धाद्यानि भास्करः । वार्षिकौ तपते मासौ रसमम्लं विवर्धयन् ॥
#   चित्रादीन्यथ चत्वारि ज्येष्ठार्धञ्च दिवाकरः । शारदौ लवणाख्यं च तपत्याप्याययन् रसम् ॥
#   ज्येष्ठार्धादीनि चत्वारि वैष्णवान्तानि भास्करः । हेमन्ते तपते मासौ मधुरं वर्धयन् रसम् ॥
#   (Ādityacāra; v. 47, 48, 52, 53, 54, 55)
# ```

# %%
# vgj_ac_rs.plot_adityachaara_seasons()
vgj_ac_rs.plot_vgj_seasons(years=[-1500])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)

# Compute pie slices
N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.viridis(r / 10.))
    bar.set_alpha(0.5)

a1= plt.thetagrids(range(0, 360, int(360/N)), labels=list('ABCDEFGHIJKLMNOPQRST'), ), 
display(dir(a1[0][1][0]))
plt.show()

# %%
yrs = [-1000]*1 + [-1500]*8
vgj_ac_rs.plot_vgj_seasons(years=yrs, equal_naks=True, title="", day_ticks=True, savefig=False )

# %% [markdown]
# ### Moon Phases per NASA astropixels <a class="anchor" id="moon-phase-nasa"></a>

# %%
for y in range(8) :
   yr = 1000 - 500*y
   vgj_ac_rs.plot_vgj_seasons(years=[yr], equal_naks=True, title="", day_ticks=True, savefig=False )
   vgj_ac_rs.plot_vgj_seasons(years=[yr, yr-500], equal_naks=True, title="", day_ticks=True, savefig=False)

# %% [markdown]
# ## Table 1. Nakṣatra Constituents and proxy stars of the 11th Section of VGJ.

# %% [markdown]
# <!-- Embed an mp4 video -->
# <hr>
#
# ### Video of the seasonal nakṣatra boundaries over epochs
# <video width="800" height="800" style="margin-top:-10px" controls>
#   <source src="./images/naks-366/ticks.mp4" type="video/mp4">
# </video>

# %%
vgj_ac_rs.naks_eq_bounds_report.set_index('#')

# %% [markdown]
# ## Path of Mars without and with Vakra
# This chart that shows
# - Mars path from Jyeshta(1) to Jyeshta(2) to Jyestha(3) .
# - Epoch is around -590
# - Mars takes ~540 days from Jyeshta(1) to Jyeshta(2) ( no Vakra)
# - Mars takes ~720 days from Jyeshta(2) to Jyeshta(3) ( Vakra)
# - The mars path is color coded - blue visible, red not visible

# %%
vgj_ac_rs.plot_n83_ll_with_mars_overlay();

# %%
vgj_ac_rs.plot_n83_rd_with_mars_overlay();

# %% [markdown]
# ## Plot of Sun-Gruha angular gap annotated with visibility and rise/set events

# %%
vgj_ac_rs.plot_gruha_elongation_and_visibility()

# %% [markdown]
# ## Venus morning/evening first/last visibility

# %%
vgj_ac_rs.Graha_Kolam().plot()

# %%
# !rm ./vgj_ac_rs.html 2>/dev/null
# !date
# !date
!`which jupyter` nbconvert vgj_ac_rs.ipynb --to html --no-input --output  vgj_ac_rs.html 2>&1 | tee ~/tmp/nbconvert.log
# !open ./vgj_ac_rs.html

# %%
import math
import time
import torch

def bmx(device,sz=1200) :
    dtype = torch.float
    start_time = time.time()
    device = torch.device(device)
    # sz = 201

    x = torch.linspace(-1*math.pi, 1*math.pi, sz, device=device, dtype=dtype)
    y = torch.sin(x)

    a = torch.randn((), device=device, dtype=dtype)
    b = torch.randn((), device=device, dtype=dtype)
    c = torch.randn((), device=device, dtype=dtype)
    d = torch.randn((), device=device, dtype=dtype)
    # print( x.shape, y.shape, a.shape, b.shape, c.shape, d.shape)

    learning_rate = 1e-6
    prev_loss = None
    for t in range(18000):
        y_pred = a + b * x + c * x ** 2 + d * x ** 3
        loss = (y_pred - y).pow(2).sum().item()
        if prev_loss is not None and loss > prev_loss :
            print(f'Loss increased from {prev_loss} to {loss}')
            break
        prev_loss = loss
        # if t<10 and t % 1 == 0: print(device, t, loss)
        # if t<1000 and t % 100 == 0: print(device, t, loss)
        if t>=1000 and t % 1000 == 0: print(device, t, loss)

        grad_y_pred = 2.0 * (y_pred - y)
        grad_a = grad_y_pred.sum()
        grad_b = (grad_y_pred * x).sum()
        grad_c = (grad_y_pred * x ** 2).sum()
        grad_d = (grad_y_pred * x ** 3).sum()
        a -= learning_rate * grad_a
        b -= learning_rate * grad_b
        c -= learning_rate * grad_c
        d -= learning_rate * grad_d

    print( x.shape, y.shape, a.shape, b.shape, c.shape, d.shape)
    end_time = time.time()
    print(f'{device} {end_time - start_time:.5f}\nResult: y = {a} + {b} x + {c} x^2 + {d} x^3\n\n')

bmx("cpu", 1400)
bmx("mps", 1400)

# %%
import torch
import time

for d in ['cpu',  'mps'] :
    try :
        device = torch.device(d)
    except Exception as e :
        print(f"Device {d} not available {e}")
        continue

    print(f"Using device: {device}")

    sz = 1024*15

    start_time = time.time()
    x = torch.randn(sz, sz).to(device)
    y = torch.randn(sz, sz).to(device)
    end_time = time.time()

    print(f"Time taken: {end_time - start_time:.5f} seconds")
    print(f"Matrix size: {x.shape}x{y.shape}")

    start_time = time.time()
    # z = x.mm(y)
    z2 = x - y
    end_time = time.time()

    print(f"Time taken: {end_time - start_time:.5f} seconds")

    print()

# %%
import torch
import time
import pandas as pd

def benchmark(func):
    def wrapper(*args, **kwargs):
        start = time.time()
        ans = func(*args, **kwargs)
        end = time.time()
        elapsed  = end - start
        # print(f"{func.__name__:10s} {elapsed:.3f} seconds")
        return ans ,(func.__name__, elapsed)
    return wrapper

@benchmark
def alloc(sz=1024, device='cpu') :
    device = torch.device(device)
    x = torch.randn(sz, sz).to(device)
    y = torch.randn(sz, sz).to(device)
    return x, y

@benchmark
def sin(x) : return torch.sin(x) 
@benchmark
def poly(x) : return x**2 + x**3
@benchmark
def matmul(x, y) : return x.mm(y)
@benchmark
def sub(x, y) : return x - y

def test_dev(sz=1024, device='cpu') :
    bms = []
    # print(f"\nTesting with size {sz}^2 matrix on device {device}")
    (x, y), bm = alloc(sz, device) ; bms.append(bm)
    _ , bm = matmul(x, y) ; bms.append(bm)
    _ , bm = sub(x, y) ; bms.append(bm)
    _ , bm = sin(x) ; bms.append(bm)
    _ , bm = poly(x) ;  bms.append(bm)
    ans = pd.DataFrame( bms, columns=['func', 'time_secs']).assign(device = device)
    # display(ans)
    return ans

def tester(sz):
    bm1 = test_dev(sz, 'cpu')
    bm2 = test_dev(sz, 'mps')
    df = pd.concat([bm1, bm2])[['device', 'func', 'time_secs']].groupby(['device', 'func']).mean().unstack()#
    df.plot.bar(logy=True, figsize=(8, 3), title=f'Benchmarking CPU vs MPS - {sz}^2 matrix')
    display(df.style.format("{:.3f}").set_caption(f'Benchmarking CPU vs MPS - {sz}^2 matrix'))

tester(1024)
tester(1024*2)
tester(1024*20)
